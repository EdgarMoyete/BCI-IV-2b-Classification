# %% [markdown]
# ### Edgar Moises Hernandez-Gonzalez
# #### 24-07-20-26-08-20
# #### Clasificacion binaria de imagenes motoras en EEG con CNN-2D
# #### Cargar modelo para evaluacion y predecir
# ##### Caracteristicas = Escalogramas CWT (3D)
# ##### Resize proporcional de 67x500

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import time
import pywt
import cv2
from sklearn.metrics import cohen_kappa_score, confusion_matrix
from keras.models import load_model

# %%
x_train = pd.read_csv("/content/drive/My Drive/BCI-IV-2b/Datos/MI-EEG-B9T.csv", header=None)
x_test = pd.read_csv("/content/drive/My Drive/BCI-IV-2b/Datos/MI-EEG-B9E.csv", header=None)
y_test = pd.read_csv("/content/drive/My Drive/BCI-IV-2b/Datos/etiquetas_test_9.csv", header=None)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (400, 3000)
# (320, 3000)
# (320, 1)

# %%
# esto se podria calcular asi n_clases = len(np.unique(y)), la y puede ser train o test
n_classes = len(np.unique(y_test))

print("n_classes:", n_classes)
# Out:
# n_classes: 2

# %%
#unir 3 canales
def unir_escalogramas_vertical(data):
  dim = (500, 67) #ancho, alto
  fs = 250
  escalas = pywt.scale2frequency('cmor3-3', np.arange(8,30.5,0.5)) / (1/fs)
  datos = np.zeros((data.shape[0],67,500))
  temporal = np.zeros((135,1000))
  for i in range(data.shape[0]): #n muestras
    for j in range(3): #3 canales
      sig = data.iloc[i, j*1000:(j+1)*1000]
      # escalograma CWT
      coef, freqs = pywt.cwt(sig, escalas, 'cmor3-3', sampling_period = (1 / fs))
      temporal[j*45:(j+1)*45, :] = abs(coef)
    resized = cv2.resize(temporal, dim, interpolation=cv2.INTER_AREA)
    datos[i] = resized
    if i % 100 == 0: #esto solo es para ver como avanza
      print(i)
  return datos

# %%
#llamar a unir_escalogramas_vertical(data)
inicio = time.time()

x_train = unir_escalogramas_vertical(x_train)
x_test = unir_escalogramas_vertical(x_test)

fin = time.time()
print("Tiempo:", fin - inicio)
# Out:
# 0
# 100
# 200
# 300
# 0
# 100
# 200
# 300
# Tiempo: 41.99726724624634

# %%
print(x_test.shape)
# Out:
# (320, 67, 500)

# %%
#convertir a float
x_test = x_test.astype('float32')

#escalar los valores en un rango de 0 a 1 (normalizar)
x_test /= np.ceil(np.max(x_train))

# %%
#convertir de 3D a 4D
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], x_test.shape[2], 1))

print(x_test.shape)
# Out:
# (320, 67, 500, 1)

# %%
model = load_model('/content/drive/My Drive/BCI-IV-2b/Modelos/CWT_CNN_09.hdf5')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 67, 500, 8)        80
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 33, 250, 8)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 33, 250, 8)        584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 125, 8)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                256016
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 256,714
# Trainable params: 256,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
inicio = time.time()

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

fin = time.time()
print("Tiempo:", fin - inicio)
# Out:
# Tiempo: 1.6551439762115479

# %%
print("loss: %.4f" % test_loss)
print("accuracy: %.4f" % test_acc)
# Out:
# loss: 0.5739
# accuracy: 0.8406

# %%
probabilidades = model.predict(x_test)
y_pred = np.argmax(probabilidades, 1) #1=fila

# %%
kappa = cohen_kappa_score(y_test, y_pred)
print("kappa: %.4f " % kappa)
# Out:
# kappa: 0.6813

# %%
matriz_confusion = confusion_matrix(y_test, y_pred)
print("confusion matrix:\n", matriz_confusion)
# Out:
# confusion matrix:
#  [[139  21]
#  [ 30 130]]

# %%
inicio = time.time()

probabilidades = model.predict(x_test[0].reshape(1,67,500,1))
y_pred = np.argmax(probabilidades, 1) #1=fila

fin = time.time()
print("Tiempo:", fin - inicio)
# Out:
# Tiempo: 0.0538637638092041
